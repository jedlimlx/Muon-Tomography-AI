# %%
import matplotlib.pyplot as plt
import numpy as np
import os
os.environ["KERAS_BACKEND"] = "tensorflow"
import keras_core as keras
import tensorflow as tf
# Out:
# 2023-07-19 21:04:18.035176: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-19 21:04:18.726518: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Using TensorFlow backend

# %%
from layers import KNN

# %%
features = np.random.uniform(size=(16384, 2))

# %%
query_point = np.random.uniform(size=(1, 2))

# %%
knn_test = KNN(100)

# %%
x = knn_test(query_point[tf.newaxis, ...], features[tf.newaxis, ...])

# %%
print(x)
# Out:
# tf.Tensor(
# [[[12139 10112  5788  1611  9941 10501 12150 15656 10431  5838  8747
#     4234  6198 13493 11884 10464  9262  1856  3743  3024  3318 12753
#    12816  9605  4763  1746 14973  3344   172  6116  8490 13701  4705
#    11789  6994 12112  3568 12257  4338 15157 13621  1244  4126  7451
#    14557  3556 11179 12593  6280  9388  6508 10528  5260  5888 12269
#    10710  5467   634 15242  2282  7871 15176  3513  3192  2358  1252
#     9103  5918   744  7163  2000  8392 14193  9523  9544 11483 13599
#    10849  4539 11933 15259   531  7107 11524  6901 10573 11554 10521
#    11898  7905  2182  4602 11598 11124  1884  6210  3717  7297 15322
#    15181]]], shape=(1, 1, 100), dtype=int32)

# %%
import pandas as pd
import seaborn as sns

# %%
query_point
# Out:
# array([[0.16798151, 0.66236162]])

# %%
df = pd.DataFrame(features, columns=['x', 'y'])
df['labels'] = '0'
df['labels'][x.numpy().flatten()] = '1'
sns.scatterplot(df, x='x', y='y', hue='labels')
plt.show()
# Out:
# /tmp/ipykernel_4027/3368511164.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['labels'][x.numpy().flatten()] = '1'

# %%
print("test")
